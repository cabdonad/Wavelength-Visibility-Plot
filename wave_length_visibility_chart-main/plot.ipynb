# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
ds = pd.read_csv('joint.csv', header=None)

# %%
ds.head()
# Out:
#                    0            1            2            3            4   \
# 0  La HYDROXY COMPLEX          NaN          NaN          NaN          NaN
# 1     Wavelength (nm)        LaHL1        LaHL2        LaHL3        NdHL1
# 2                 500  0.345742494  0.941114962  0.167430326  0.018460212
# 3                 499  0.346005946  0.941880047  0.168293342  0.018089848
# 4                 498  0.345516503  0.943599463  0.168985218  0.018428909
#
#             5            6            7            8            9   \
# 0          NaN          NaN          NaN          NaN          NaN
# 1        NdHL2       NdHHL3        DyHL1        DyHL2        DyHL3
# 2  0.186429292  0.165707633   0.15525353  0.173880145  0.799477041
# 3  0.186587229  0.165717214  0.155411512  0.174622536  0.802765369
# 4   0.18628414   0.16606991  0.156594619  0.175292566  0.807462037
#
#             10           11           12
# 0          NaN          NaN          NaN
# ...

# %%
ds.columns = ['Wavelength','LaHL1','LaHL2','LaHL3','NdHL1','NdHL2','NdHHL3','DyHL1','DyHL2','DyHL3','HL1','HL2','HL3']
ds.head()
# Out:
#            Wavelength        LaHL1        LaHL2        LaHL3        NdHL1  \
# 0  La HYDROXY COMPLEX          NaN          NaN          NaN          NaN
# 1     Wavelength (nm)        LaHL1        LaHL2        LaHL3        NdHL1
# 2                 500  0.345742494  0.941114962  0.167430326  0.018460212
# 3                 499  0.346005946  0.941880047  0.168293342  0.018089848
# 4                 498  0.345516503  0.943599463  0.168985218  0.018428909
#
#          NdHL2       NdHHL3        DyHL1        DyHL2        DyHL3  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1        NdHL2       NdHHL3        DyHL1        DyHL2        DyHL3
# 2  0.186429292  0.165707633   0.15525353  0.173880145  0.799477041
# 3  0.186587229  0.165717214  0.155411512  0.174622536  0.802765369
# 4   0.18628414   0.16606991  0.156594619  0.175292566  0.807462037
#
#            HL1          HL2          HL3
# 0          NaN          NaN          NaN
# ...

# %%
ds = ds[2:-1]
ds.head()
# Out:
#   Wavelength        LaHL1        LaHL2        LaHL3        NdHL1        NdHL2  \
# 2        500  0.345742494  0.941114962  0.167430326  0.018460212  0.186429292
# 3        499  0.346005946  0.941880047  0.168293342  0.018089848  0.186587229
# 4        498  0.345516503  0.943599463  0.168985218  0.018428909   0.18628414
# 5        497   0.34608382  0.944834948  0.169099018  0.019033229  0.186675385
# 6        496  0.346835464  0.946508884  0.169797242  0.018621763  0.186761975
#
#         NdHHL3        DyHL1        DyHL2        DyHL3          HL1  \
# 2  0.165707633   0.15525353  0.173880145  0.799477041  0.203811407
# 3  0.165717214  0.155411512  0.174622536  0.802765369  0.204851583
# 4   0.16606991  0.156594619  0.175292566  0.807462037  0.205324873
# 5  0.166630462  0.156700805  0.176461056  0.811000228  0.206329748
# 6  0.166760415  0.157205224  0.177401245  0.815741718  0.205643252
#
#            HL2          HL3
# 2  0.346649706  0.067584604
# 3  0.348544926  0.068329439
# ...

# %%
sns.lineplot(ds, x='Wavelength',y='LaHL2')
# Out:
# <Axes: xlabel='Wavelength', ylabel='LaHL2'>
